# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonsy22/NLP_2023/blob/main/pandas_%EA%B8%B0%EB%B3%B82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df01 = pd.DataFrame({'학번': [20121, 20111, 202243, 20312, 20513],
                   '이름': ['이학생', '권학생', '최학생', '김학생', '박학생'],
                   '국어': [80, 90, 93, 97, 84],
                   '영어': [87, 79, 91, 95, 90]},
                   index = [0, 1, 2, 3, 4])

df01
# Out:
#        학번   이름  국어  영어
# 0   20121  이학생  80  87
# 1   20111  권학생  90  79
# 2  202243  최학생  93  91
# 3   20312  김학생  97  95
# 4   20513  박학생  84  90

# %%
df01.loc[2]
# Out:
# 학번    202243
# 이름       최학생
# 국어        93
# 영어        91
# Name: 2, dtype: object

# %%
df01.loc[3, '영어']
# Out:
# 95

# %%
df01.loc[:, :]
# Out:
#        학번   이름  국어  영어
# 0   20121  이학생  80  87
# 1   20111  권학생  90  79
# 2  202243  최학생  93  91
# 3   20312  김학생  97  95
# 4   20513  박학생  84  90

# %%
df01.loc[:,'이름']
# Out:
# 0    이학생
# 1    권학생
# 2    최학생
# 3    김학생
# 4    박학생
# Name: 이름, dtype: object

# %%
df01.loc[:2, :'국어']
# Out:
#        학번   이름  국어
# 0   20121  이학생  80
# 1   20111  권학생  90
# 2  202243  최학생  93

# %%
df01['국어']>90
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: 국어, dtype: bool

# %%
df02 = df01['국어'] > 90
df02
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: 국어, dtype: bool

# %%
df03 = df01.loc[df02]
df03
# Out:
#        학번   이름  국어  영어
# 2  202243  최학생  93  91
# 3   20312  김학생  97  95
