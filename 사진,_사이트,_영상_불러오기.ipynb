# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonsy22/NLP_2023/blob/main/%EC%82%AC%EC%A7%84%2C_%EC%82%AC%EC%9D%B4%ED%8A%B8%2C_%EC%98%81%EC%83%81_%EB%B6%88%EB%9F%AC%EC%98%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U IPython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.2/808.2 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 1.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: IPython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.18.1 which is incompatible.
# ...

# %%
from IPython.display import Image
Image('https://cdn.topstarnews.net/news/photo/202311/15422084_1204638_3455.jpg')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('3UhUYqJkWGw?feature=shared') #채널번호, 고유번호만 사용
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/3UhUYqJkWGw?feature=shared"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ji_hVYmi4mY?feature=shared')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/ji_hVYmi4mY?feature=shared"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import HTML
HTML('웹사이트 주소')
# Out:
# 웹사이트 주소

# %%
from IPython.display import HTML
HTML('https://google.co.kr/')
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="zh-TW"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="Gq9XjzdvBuS5nqZrspNa5Q">(function(){var _g={kEI:'HOppZY3gJIOp-QbdgqngBA',kEXPI:'0,1303564,61903,207,4804,2316,383,1129371,1920,1195796,380775,16114,28684,22430,1362,12317,17582,4998,17075,38444,2872,2891,3926,4423,3405,606,60690,2614,13721,20583,4,59617,4437,22613,6624,7596,1,42154,2,39761,5679,1021,31122,4568,6258,23418,1252,30152,2912,2,2,1,26632,8155,23351,873,19633,8,1921,9779,42459,20198,20137,14,82,20206,27337,5403,3030,11151,4665,1804,35268,5487,6327,1632,3244,6466,3785,21121,5231885,2,580,132,50,32,498,152,5991661,650,1210,2803214,3311,141,795,30314,2,2,2,2,2,35,23940208,397,4043710,16672,40904,2983,3,1603,3,499,3,1393942,727334,23031936,11557,1242,8408,2879,336,1262,6426,3796,1396,2,5509,6421,
# ...

# %%
from IPython.display import HTML
HTML('https://www.naver.com')
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...
